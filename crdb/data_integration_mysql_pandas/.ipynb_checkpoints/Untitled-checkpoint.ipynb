# %%
# DATA INTEGRATION

# %%
# SQL Magic Commands,allows you to write native SQL queries directly in 
# dedicated cells within the notebook using "magic commands (Run Once)

# !pip install ipython-sql

# %%
# Load the SQL extension and connect to your database using a connection string:

# %load_ext sql
# %sql mysql://root:@host/crdb
# Out:
# The sql extension is already loaded. To reload it, use:
#   %reload_ext sql
# Traceback (most recent call last):
#   File "/home/maquiz/Documents/WORKS/interviews/crdb/data_integration/venv-data-integration/lib/python3.10/site-packages/sql/connection.py", line 45, in __init__
#     engine = sqlalchemy.create_engine(
#   File "<string>", line 2, in create_engine
#   File "/home/maquiz/Documents/WORKS/interviews/crdb/data_integration/venv-data-integration/lib/python3.10/site-packages/sqlalchemy/util/deprecations.py", line 281, in warned
#     return fn(*args, **kwargs)  # type: ignore[no-any-return]
#   File "/home/maquiz/Documents/WORKS/interviews/crdb/data_integration/venv-data-integration/lib/python3.10/site-packages/sqlalchemy/engine/create.py", line 617, in create_engine
#     dbapi = dbapi_meth(**dbapi_args)
# ...

# %%
# Execute SQL commands in a cell by prefixing the line with %sql (for a single line) or
# the entire cell with %%sql (for multi-line queries

# %%sql
SELECT *
FROM your_table_name
LIMIT 5;
# Out:
# /tmp/ipykernel_193369/3845843239.py:3: UserWarning: pandas only supports SQLAlchemy connectable (engine/connection) or database string URI or sqlite3 DBAPI2 connection. Other DBAPI2 objects are not tested. Please consider using SQLAlchemy.
#   df = pd.read_sql(query, conn)
# ---------------------------------------------------------------------------
# MySQLInterfaceError                       Traceback (most recent call last)
# File ~/Documents/WORKS/interviews/crdb/data_integration/venv-data-integration/lib/python3.10/site-packages/mysql/connector/connection_cext.py:772, in CMySQLConnection.cmd_query(self, query, raw, buffered, raw_as_string, **kwargs)
#     770     self._local_infile_filenames = None
# --> 772     self._cmysql.query(
#     773         query,
#     774         raw=raw,
#     775         buffered=buffered,
#     776         raw_as_string=raw_as_string,
#     777         query_attrs=self.query_attrs,
#     778     )
#     779 except MySQLInterfaceError as err:
#
# ...
